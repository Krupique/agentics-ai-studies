# %%
import yfinance as yf
import matplotlib.pyplot as plt

ticker = yf.Ticker("BTLG11.SA")

# Histórico de preços
preco = ticker.history(period="6mo")

# Dividendos
dividendos = ticker.dividends

print("Últimos preços:")
print(preco.tail())

print("\nÚltimos dividendos:")
print(dividendos.tail())

# Gráfico de preço
preco["Close"].plot(title="BTLG11 - Preço")
plt.show()
# Out:
# Últimos preços:
#                                 Open        High        Low      Close  \
# Date
# 2026-09-02 00:00:00-03:00  99.199997   99.269997  98.870003  98.980003
# 2026-09-03 00:00:00-03:00  99.059998   99.139999  98.910004  99.000000
# 2026-09-04 00:00:00-03:00  99.099998   99.139999  98.739998  99.139999
# 2026-09-08 00:00:00-03:00  99.300003  100.400002  99.260002  99.430000
# 2026-09-09 00:00:00-03:00  99.959999  100.650002  99.349998  99.879997
#
#                            Volume  Dividends  Stock Splits
# Date
# 2026-09-02 00:00:00-03:00  174597        0.0           0.0
# 2026-09-03 00:00:00-03:00  213574        0.0           0.0
# 2026-09-04 00:00:00-03:00  212722        0.0           0.0
# 2026-09-08 00:00:00-03:00  296584        0.0           0.0
# 2026-09-09 00:00:00-03:00  262711        0.0           0.0
#
# Últimos dividendos:
# Date
# 2026-04-16 00:00:00-03:00    0.808105
# 2026-05-18 00:00:00-03:00    0.810000
# 2026-06-16 00:00:00-03:00    0.810000
# 2026-07-16 00:00:00-03:00    0.810000
# 2026-08-17 00:00:00-03:00    0.810000
# Name: Dividends, dtype: float64
