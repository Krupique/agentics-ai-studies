# %%
import os
import socket
from dotenv import load_dotenv
from phi.agent import Agent  
from phi.model.groq import Groq  
from phi.tools.duckduckgo import DuckDuckGo  
from phi.tools.yfinance import YFinanceTools

# %%
# Loading environment variables
if load_dotenv():
    print("[INFO] Env variables sucessfully loaded.")
else:
    print("[WARNING] .env file not found. Some settings may be missing.")
# Out:
# [INFO] Env variables sucessfully loaded.

# %%
# Check internet connection
def check_connection():
    try:
        socket.create_connection(("www.google.com", 80), timeout=5)
        print("[INFO] Interet connection checked.")
        return True
    except OSError:
        print("[ERROR] No internet connection! Some frameworks may not work.")
        return False

# %%
flag_conn = check_connection()

# Creating AI Agents
print("[INFO] Starting agents...")
# Out:
# [INFO] Interet connection checked.
# [INFO] Starting agents...

# %%
# Financial Agent
fin_agent = Agent(name="Financial Agent",  
                  model=Groq(id="llama-3.3-70b-versatile"),
                  tools=[YFinanceTools(stock_price=True,  
                                       analyst_recommendations=True,  
                                       stock_fundamentals=True)] if flag_conn else [],
                                       show_tool_calls=True,  
                                       markdown=True,  
                                       instructions=["Generate tables to comparasions", "Generate the results in English"])

# %%
# Search Agent
search_agent = Agent(name="Pesquisador Web",  
                            model=Groq(id="llama-3.3-70b-versatile"),
                            tools=[DuckDuckGo()] if flag_conn else [],
                            show_tool_calls=True,  
                            markdown=True,  
                            instructions=["You always need to include the references you collect",
                                          "Generate the results in English",
                                          "Use always reliable sources, you are a senior financial analyst"
                                          ])

# %%
# Team agents
team_agents = Agent(team=[fin_agent, search_agent], 
                         model=Groq(id="llama-3.3-70b-versatile"),
                         show_tool_calls=True,  
                         markdown=True,  
                         instructions=["Includes the sources of the collected informations always",
                                       "Create tables to compare",
                                       "Generate the results in English"
                                       ],
                         debug_mode=True)
# Out:
# DEBUG    Debug logs enabled

# %%
print("[INFO] Collecting informations and recommendations about the APPLE...")

response = ""

for delta in team_agents.run("Summaryze the recomendations from the analysts about the investments and share the lastest informations and news about the Apple."):
    if isinstance(delta, tuple) and delta[0] == "content":
        response += delta[1]
# Out:
# [INFO] Collecting informations and recommendations about the APPLE...
# DEBUG    *********** Agent Run Start: fbc19b1f-3cff-4dac-9d7f-cd7870fd1927 ***********
# DEBUG    Function transfer_task_to_financial_agent added to model.
# DEBUG    Function transfer_task_to_pesquisador_web added to model.
# DEBUG    ---------- Groq Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## You are the leader of a team of AI Agents.
#            - You can either respond directly or transfer tasks to other Agents in your team depending on the tools
#          available to them.
#            - If you transfer a task to another Agent, make sure to include a clear description of the task and the
#          expected output.
#            - You must always validate the output of the other Agents before responding to the user, you can
#          re-assign the task if you are not satisfied with the result.
#
#          ## Instructions
#          - Includes the sources of the collected informations always
#          - Create tables to compare
#          - Generate the results in English
#          - Use markdown to format your answers.
#
#          ## Agents in your team:
#          You can transfer tasks to the following agents:
#          Agent 1:
#          Name: Financial Agent
#          Available tools: get_current_stock_price, get_stock_fundamentals, get_analyst_recommendations
#
#          Agent 2:
#          Name: Pesquisador Web
#          Available tools: duckduckgo_search, duckduckgo_news
# DEBUG    ============== user ==============
# DEBUG    Summaryze the recomendations from the analysts about the investments and share the lastest informations
#          and news about the Apple.
# DEBUG    ============== assistant ==============
# DEBUG    Tool Calls: [
#            {
#              "id": "tax9wzt73",
#              "function": {
#                "arguments": "{\"additional_information\":\"Investments and Apple stocks\",\"expected_output\":\"A
#          summary of analyst recommendations\",\"task_description\":\"Get analyst recommendations for
#          investments\"}",
#                "name": "transfer_task_to_financial_agent"
#              },
#              "type": "function"
#            },
#            {
#              "id": "5z5w9rw39",
#              "function": {
#                "arguments": "{\"additional_information\":\"Apple stocks and news\",\"expected_output\":\"Latest
#          information about Apple\",\"task_description\":\"Get the latest information about Apple\"}",
#                "name": "transfer_task_to_financial_agent"
#              },
#              "type": "function"
#            },
#            {
#              "id": "a7r1x5f3f",
#              "function": {
#                "arguments": "{\"additional_information\":\"Apple news and updates\",\"expected_output\":\"Latest
#          news about Apple\",\"task_description\":\"Get the latest news about Apple\"}",
#                "name": "transfer_task_to_pesquisador_web"
#              },
#              "type": "function"
#            }
#          ]
# DEBUG    **************** METRICS START ****************
# DEBUG    * Time to generate response:   0.9436s
# DEBUG    * Tokens per second:           143.0618 tokens/s
# DEBUG    * Input tokens:                920
# DEBUG    * Output tokens:               135
# DEBUG    * Total tokens:                1055
# DEBUG    * Completion time:             0.3685s
# DEBUG    * Prompt time:                 0.0497s
# DEBUG    * Queue time:                  0.3129s
# DEBUG    * Total time:                  0.4183s
# DEBUG    **************** METRICS END ******************
# DEBUG    Getting function transfer_task_to_financial_agent
# DEBUG    Getting function transfer_task_to_financial_agent
# DEBUG    Getting function transfer_task_to_pesquisador_web
# DEBUG    Running: transfer_task_to_financial_agent(additional_information=Investments and Apple stocks,
#          expected_output=A summary of analyst recommendations, task_description=Get analyst recommendations for
#          investments)
# DEBUG    *********** Agent Run Start: 48f99569-1498-4a30-bbf7-c2fdb71a436f ***********
# DEBUG    Function get_current_stock_price from yfinance_tools added to model.
# DEBUG    Function get_stock_fundamentals from yfinance_tools added to model.
# DEBUG    Function get_analyst_recommendations from yfinance_tools added to model.
# DEBUG    ---------- Groq Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## Instructions
#          - Generate tables to comparasions
#          - Generate the results in English
#          - Use markdown to format your answers.
# DEBUG    ============== user ==============
# DEBUG    Get analyst recommendations for investments
#
#          The expected output is: A summary of analyst recommendations
#
#          Additional information: Investments and Apple stocks
# DEBUG    ============== assistant ==============
# DEBUG    ### Analyst Recommendations for Apple Stock
#          To get analyst recommendations for Apple stock, we need to use the function `get_analyst_recommendations`
#          with the symbol 'AAPL'.
# DEBUG    Tool Calls: [
#            {
#              "id": "1y2sws1bz",
#              "function": {
#                "arguments": "{\"symbol\":\"AAPL\"}",
#                "name": "get_analyst_recommendations"
#              },
#              "type": "function"
#            }
#          ]
# DEBUG    **************** METRICS START ****************
# DEBUG    * Time to generate response:   0.6352s
# DEBUG    * Tokens per second:           88.1569 tokens/s
# DEBUG    * Input tokens:                452
# DEBUG    * Output tokens:               56
# DEBUG    * Total tokens:                508
# DEBUG    * Completion time:             0.1598s
# DEBUG    * Prompt time:                 0.0943s
# DEBUG    * Queue time:                  0.2857s
# DEBUG    * Total time:                  0.2542s
# DEBUG    **************** METRICS END ******************
# DEBUG    Getting function get_analyst_recommendations
# DEBUG    Running: get_analyst_recommendations(symbol=AAPL)
# DEBUG    ---------- Groq Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## Instructions
#          - Generate tables to comparasions
#          - Generate the results in English
#          - Use markdown to format your answers.
# DEBUG    ============== user ==============
# DEBUG    Get analyst recommendations for investments
#
#          The expected output is: A summary of analyst recommendations
#
#          Additional information: Investments and Apple stocks
# DEBUG    ============== assistant ==============
# DEBUG    ### Analyst Recommendations for Apple Stock
#          To get analyst recommendations for Apple stock, we need to use the function `get_analyst_recommendations`
#          with the symbol 'AAPL'.
# DEBUG    Tool Calls: [
#            {
#              "id": "1y2sws1bz",
#              "function": {
#                "arguments": "{\"symbol\":\"AAPL\"}",
#                "name": "get_analyst_recommendations"
#              },
#              "type": "function"
#            }
#          ]
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: 1y2sws1bz
# DEBUG    {"0":{"period":"0m","strongBuy":6,"buy":25,"hold":15,"sell":1,"strongSell":1},"1":{"period":"-1m","strongB
#          uy":5,"buy":25,"hold":16,"sell":1,"strongSell":1},"2":{"period":"-2m","strongBuy":6,"buy":24,"hold":15,"se
#          ll":1,"strongSell":2},"3":{"period":"-3m","strongBuy":5,"buy":24,"hold":15,"sell":1,"strongSell":3}}
# DEBUG    ============== assistant ==============
# DEBUG    ### Analyst Recommendations Summary
#          The analyst recommendations for Apple (AAPL) stock are as follows:
#          - Strong Buy: 6
#          - Buy: 25
#          - Hold: 15
#          - Sell: 1
#          - Strong Sell: 1
#
#          Note: The numbers represent the number of analysts with each recommendation.
# DEBUG    **************** METRICS START ****************
# DEBUG    * Time to generate response:   0.5855s
# DEBUG    * Tokens per second:           111.0108 tokens/s
# DEBUG    * Input tokens:                600
# DEBUG    * Output tokens:               65
# DEBUG    * Total tokens:                665
# DEBUG    * Completion time:             0.1810s
# DEBUG    * Prompt time:                 0.0331s
# DEBUG    * Queue time:                  0.2735s
# DEBUG    * Total time:                  0.2141s
# DEBUG    **************** METRICS END ******************
# DEBUG    ---------- Groq Response End ----------
# DEBUG    Added 4 Messages to AgentMemory
# DEBUG    Added AgentRun to AgentMemory
# DEBUG    --**-- Logging Agent Run
# DEBUG    *********** Agent Run End: 48f99569-1498-4a30-bbf7-c2fdb71a436f ***********
# DEBUG    Running: transfer_task_to_financial_agent(additional_information=Apple stocks and news,
#          expected_output=Latest information about Apple, task_description=Get the latest information about Apple)
# DEBUG    *********** Agent Run Start: 5d094e75-a82f-4b24-9640-6b35d5a22a61 ***********
# DEBUG    ---------- Groq Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## Instructions
#          - Generate tables to comparasions
#          - Generate the results in English
#          - Use markdown to format your answers.
# DEBUG    ============== user ==============
# DEBUG    Get the latest information about Apple
#
#          The expected output is: Latest information about Apple
#
#          Additional information: Apple stocks and news
# DEBUG    ============== assistant ==============
# DEBUG    ### Latest Information About Apple
#          To get the latest information about Apple, we need to consider various factors such as its stock price,
#          fundamentals, and analyst recommendations.
# DEBUG    Tool Calls: [
#            {
#              "id": "p4pjp8dhe",
#              "function": {
#                "arguments": "{\"symbol\":\"AAPL\"}",
#                "name": "get_current_stock_price"
#              },
#              "type": "function"
#            },
#            {
#              "id": "xdzzctsfk",
#              "function": {
#                "arguments": "{\"symbol\":\"AAPL\"}",
#                "name": "get_stock_fundamentals"
#              },
#              "type": "function"
#            },
#            {
#              "id": "8b4vj0a5h",
#              "function": {
#                "arguments": "{\"symbol\":\"AAPL\"}",
#                "name": "get_analyst_recommendations"
#              },
#              "type": "function"
#            }
#          ]
# DEBUG    **************** METRICS START ****************
# DEBUG    * Time to generate response:   0.6807s
# DEBUG    * Tokens per second:           124.8798 tokens/s
# DEBUG    * Input tokens:                452
# DEBUG    * Output tokens:               85
# DEBUG    * Total tokens:                537
# DEBUG    * Completion time:             0.2200s
# DEBUG    * Prompt time:                 0.0745s
# DEBUG    * Queue time:                  0.2852s
# DEBUG    * Total time:                  0.2944s
# DEBUG    **************** METRICS END ******************
# DEBUG    Getting function get_current_stock_price
# DEBUG    Getting function get_stock_fundamentals
# DEBUG    Getting function get_analyst_recommendations
# DEBUG    Running: get_current_stock_price(symbol=AAPL)
# DEBUG    Running: get_stock_fundamentals(symbol=AAPL)
# DEBUG    Running: get_analyst_recommendations(symbol=AAPL)
# DEBUG    ---------- Groq Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## Instructions
#          - Generate tables to comparasions
#          - Generate the results in English
#          - Use markdown to format your answers.
# DEBUG    ============== user ==============
# DEBUG    Get the latest information about Apple
#
#          The expected output is: Latest information about Apple
#
#          Additional information: Apple stocks and news
# DEBUG    ============== assistant ==============
# DEBUG    ### Latest Information About Apple
#          To get the latest information about Apple, we need to consider various factors such as its stock price,
#          fundamentals, and analyst recommendations.
# DEBUG    Tool Calls: [
#            {
#              "id": "p4pjp8dhe",
#              "function": {
#                "arguments": "{\"symbol\":\"AAPL\"}",
#                "name": "get_current_stock_price"
#              },
#              "type": "function"
#            },
#            {
#              "id": "xdzzctsfk",
#              "function": {
#                "arguments": "{\"symbol\":\"AAPL\"}",
#                "name": "get_stock_fundamentals"
#              },
#              "type": "function"
#            },
#            {
#              "id": "8b4vj0a5h",
#              "function": {
#                "arguments": "{\"symbol\":\"AAPL\"}",
#                "name": "get_analyst_recommendations"
#              },
#              "type": "function"
#            }
#          ]
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: p4pjp8dhe
# DEBUG    252.6800
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: xdzzctsfk
# DEBUG    {
#            "symbol": "AAPL",
#            "company_name": "Apple Inc.",
#            "sector": "Technology",
#            "industry": "Consumer Electronics",
#            "market_cap": 3713871642624,
#            "pe_ratio": 27.125353,
#            "pb_ratio": 42.127373,
#            "dividend_yield": 0.41,
#            "eps": 7.9,
#            "beta": 1.116,
#            "52_week_high": 288.62,
#            "52_week_low": 169.21
#          }
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: 8b4vj0a5h
# DEBUG    {"0":{"period":"0m","strongBuy":6,"buy":25,"hold":15,"sell":1,"strongSell":1},"1":{"period":"-1m","strongB
#          uy":5,"buy":25,"hold":16,"sell":1,"strongSell":1},"2":{"period":"-2m","strongBuy":6,"buy":24,"hold":15,"se
#          ll":1,"strongSell":2},"3":{"period":"-3m","strongBuy":5,"buy":24,"hold":15,"sell":1,"strongSell":3}}
# DEBUG    ============== assistant ==============
# DEBUG    ## Latest Information About Apple
#          The current stock price of Apple (AAPL) is $252.68.
#
#          ### Stock Fundamentals
#          Here are the latest fundamentals for Apple:
#          * **Company Name:** Apple Inc.
#          * **Sector:** Technology
#          * **Industry:** Consumer Electronics
#          * **Market Cap:** $3,713,871,642,624
#          * **P/E Ratio:** 27.13
#          * **P/B Ratio:** 42.13
#          * **Dividend Yield:** 0.41
#          * **EPS:** 7.9
#          * **Beta:** 1.12
#          * **52-Week High:** $288.62
#          * **52-Week Low:** $169.21
#
#          ### Analyst Recommendations
#          The latest analyst recommendations for Apple are:
#          * **Strong Buy:** 6
#          * **Buy:** 25
#          * **Hold:** 15
#          * **Sell:** 1
#          * **Strong Sell:** 1
#
#          Note: The analyst recommendations are based on the latest data available and may not reflect the current
#          market situation.
# DEBUG    **************** METRICS START ****************
# DEBUG    * Time to generate response:   0.9620s
# DEBUG    * Tokens per second:           226.6193 tokens/s
# DEBUG    * Input tokens:                766
# DEBUG    * Output tokens:               218
# DEBUG    * Total tokens:                984
# DEBUG    * Completion time:             0.5828s
# DEBUG    * Prompt time:                 0.0395s
# DEBUG    * Queue time:                  0.2572s
# DEBUG    * Total time:                  0.6223s
# DEBUG    **************** METRICS END ******************
# DEBUG    ---------- Groq Response End ----------
# DEBUG    Added 6 Messages to AgentMemory
# DEBUG    Added AgentRun to AgentMemory
# DEBUG    --**-- Logging Agent Run
# DEBUG    *********** Agent Run End: 5d094e75-a82f-4b24-9640-6b35d5a22a61 ***********
# DEBUG    Running: transfer_task_to_pesquisador_web(additional_information=Apple news and updates,
#          expected_output=Latest news about Apple, task_description=Get the latest news about Apple)
# DEBUG    *********** Agent Run Start: f08c0cfb-69cb-42d4-ba8a-ba0ef5f3c6c3 ***********
# DEBUG    Function duckduckgo_search from duckduckgo added to model.
# DEBUG    Function duckduckgo_news from duckduckgo added to model.
# DEBUG    ---------- Groq Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## Instructions
#          - You always need to include the references you collect
#          - Generate the results in English
#          - Use always reliable sources, you are a senior financial analyst
#          - Use markdown to format your answers.
# DEBUG    ============== user ==============
# DEBUG    Get the latest news about Apple
#
#          The expected output is: Latest news about Apple
#
#          Additional information: Apple news and updates
# DEBUG    ============== assistant ==============
# DEBUG    Tool Calls: [
#            {
#              "id": "jjt7w2bzh",
#              "function": {
#                "arguments": "{\"max_results\":5,\"query\":\"Apple news and updates\"}",
#                "name": "duckduckgo_news"
#              },
#              "type": "function"
#            }
#          ]
# DEBUG    **************** METRICS START ****************
# DEBUG    * Time to generate response:   0.5002s
# DEBUG    * Tokens per second:           51.9831 tokens/s
# DEBUG    * Input tokens:                433
# DEBUG    * Output tokens:               26
# DEBUG    * Total tokens:                459
# DEBUG    * Completion time:             0.0384s
# DEBUG    * Prompt time:                 0.1108s
# DEBUG    * Queue time:                  0.2757s
# DEBUG    * Total time:                  0.1492s
# DEBUG    **************** METRICS END ******************
# DEBUG    Getting function duckduckgo_news
# DEBUG    Running: duckduckgo_news(max_results=5, query=Apple news and updates)
# DEBUG    Searching DDG news for: Apple news and updates
# c:\Users\krupc\anaconda3\envs\pyagent\Lib\site-packages\phi\tools\duckduckgo.py:86: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   ddgs = DDGS(
# DEBUG    ---------- Groq Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## Instructions
#          - You always need to include the references you collect
#          - Generate the results in English
#          - Use always reliable sources, you are a senior financial analyst
#          - Use markdown to format your answers.
# DEBUG    ============== user ==============
# DEBUG    Get the latest news about Apple
#
#          The expected output is: Latest news about Apple
#
#          Additional information: Apple news and updates
# DEBUG    ============== assistant ==============
# DEBUG    Tool Calls: [
#            {
#              "id": "jjt7w2bzh",
#              "function": {
#                "arguments": "{\"max_results\":5,\"query\":\"Apple news and updates\"}",
#                "name": "duckduckgo_news"
#              },
#              "type": "function"
#            }
#          ]
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: jjt7w2bzh
# DEBUG    [
#            {
#              "date": "2026-03-24T15:02:00+00:00",
#              "title": "Apple to host June developer conference online with AI updates",
#              "body": "Apple will host its annual Worldwide Developers Conference in June, showcasing AI
#          advancements and new software. Maps ads are coming.",
#              "url": "https://www.usatoday.com/story/tech/news/2026/03/24/apple-developer-event-june/89299084007/",
#              "image":
#          "https://www.usatoday.com/gcdn/authoring/authoring-images/2026/03/24/USAT/89299212007-20260323-t-175601-z-
#          1594634130-rc-249-eazljbx-rtrmadp-3-applewwdc.JPG?crop=7314,4114,x0,y381&width=3200&height=1800&format=pjp
#          g&auto=webp",
#              "source": "USA TODAY"
#            },
#            {
#              "date": "2026-03-20T20:56:00+00:00",
#              "title": "Conservative watchdog calls for FTC to probe Apple News over 'anticompetitive behavior,
#          deceptive practices'",
#              "body": "The MRC is urging the FTC to investigate Apple News, alleging the app published zero
#          right-leaning stories in January while favoring left-leaning outlets.",
#              "url":
#          "https://www.msn.com/en-us/news/technology/conservative-watchdog-calls-for-ftc-to-probe-apple-news-over-an
#          ticompetitive-behavior-deceptive-practices/ar-AA1Z4JCM",
#              "image": "https://static.foxnews.com/foxnews.com/content/uploads/2026/03/apple.jpg",
#              "source": "Fox News"
#            },
#            {
#              "date": "2026-03-24T18:30:00+00:00",
#              "title": "Apple's AirDrop Feature Is Now Available on Select Androids Worldwide",
#              "body": "Samsung's Galaxy S26 has joined the Google Pixel 10 family of smartphones as the only
#          non-Apple devices to support Apple's popular AirDrop service.",
#              "url": "https://www.techrepublic.com/article/news-samsung-galaxy-s26-airdrop-support/",
#              "image": "https://assets.techrepublic.com/uploads/2026/03/airdrop.jpg",
#              "source": "TechRepublic"
#            },
#            {
#              "date": "2026-03-24T18:03:00+00:00",
#              "title": "Apple Confirms It's Bringing Ads to Maps as Part of New Apple Business Platform",
#              "body": "Bloomberg first reported on Apple's plans last October, and now Apple has confirmed it's a
#          reality and part of a new platform called Apple Business, launching April 14, offering advertising
#          opportunities across not only Maps but also Mail, Wallet and Siri.",
#              "url": "https://www.cnet.com/tech/services-and-software/apple-maps-ads-apple-business/",
#              "image":
#          "https://www.cnet.com/a/img/resize/bbc3ec94ba55efe4fd175fda7630ef2359131662/hub/2025/06/10/760c8712-2a70-4
#          6ab-b3bf-af4ccc590233/wwdc25map-os.jpg?auto=webp&fit=crop&height=675&width=1200",
#              "source": "CNET"
#            },
#            {
#              "date": "2026-03-24T16:56:00+00:00",
#              "title": "Apple Announces WWDC 2026: What to Expect From iOS 27, Siri Revamp",
#              "body": "Apple announces WWDC 2026, with iOS 27, major Siri AI upgrades, and a renewed focus on bug
#          fixes and performance improvements across devices.",
#              "url": "https://www.techrepublic.com/article/news-apple-wwdc-2026-ios-27-siri-ai-updates/",
#              "image": "https://assets.techrepublic.com/uploads/2026/03/tr-03242026-apple-wwdc-2026.jpg",
#              "source": "TechRepublic"
#            }
#          ]
# DEBUG    ============== assistant ==============
# DEBUG    ## Latest News About Apple
#          The latest news about Apple includes several updates and announcements. Here are some of the key points:
#          * Apple will host its annual Worldwide Developers Conference in June, showcasing AI advancements and new
#          software, including Maps ads.
#          * A conservative watchdog has called for the FTC to probe Apple News over allegations of anticompetitive
#          behavior and deceptive practices.
#          * Apple's AirDrop feature is now available on select Android devices, including the Samsung Galaxy S26.
#          * Apple has confirmed that it will bring ads to Maps as part of a new platform called Apple Business,
#          which will also offer advertising opportunities across Mail, Wallet, and Siri.
#          * Apple has announced WWDC 2026, which will include updates on iOS 27, a major Siri AI upgrade, and a
#          renewed focus on bug fixes and performance improvements across devices.
#
#          ### References:
#          * [USA TODAY](https://www.usatoday.com/story/tech/news/2026/03/24/apple-developer-event-june/89299084007/)
#          * [Fox
#          News](https://www.msn.com/en-us/news/technology/conservative-watchdog-calls-for-ftc-to-probe-apple-news-ov
#          er-anticompetitive-behavior-deceptive-practices/ar-AA1Z4JCM)
#          * [TechRepublic](https://www.techrepublic.com/article/news-samsung-galaxy-s26-airdrop-support/)
#          * [CNET](https://www.cnet.com/tech/services-and-software/apple-maps-ads-apple-business/)
#          * [TechRepublic](https://www.techrepublic.com/article/news-apple-wwdc-2026-ios-27-siri-ai-updates/)
# DEBUG    **************** METRICS START ****************
# DEBUG    * Time to generate response:   1.2776s
# DEBUG    * Tokens per second:           266.9082 tokens/s
# DEBUG    * Input tokens:                1381
# DEBUG    * Output tokens:               341
# DEBUG    * Total tokens:                1722
# DEBUG    * Completion time:             0.7774s
# DEBUG    * Prompt time:                 0.1421s
# DEBUG    * Queue time:                  0.2786s
# DEBUG    * Total time:                  0.9194s
# DEBUG    **************** METRICS END ******************
# DEBUG    ---------- Groq Response End ----------
# DEBUG    Added 4 Messages to AgentMemory
# DEBUG    Added AgentRun to AgentMemory
# DEBUG    --**-- Logging Agent Run
# DEBUG    *********** Agent Run End: f08c0cfb-69cb-42d4-ba8a-ba0ef5f3c6c3 ***********
# DEBUG    ---------- Groq Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## You are the leader of a team of AI Agents.
#            - You can either respond directly or transfer tasks to other Agents in your team depending on the tools
#          available to them.
#            - If you transfer a task to another Agent, make sure to include a clear description of the task and the
#          expected output.
#            - You must always validate the output of the other Agents before responding to the user, you can
#          re-assign the task if you are not satisfied with the result.
# ...
#           - get_analyst_recommendations(symbol=AAPL)
#
#          ### Analyst Recommendations Summary
#          The analyst recommendations for Apple (AAPL) stock are as follows:
#          - Strong Buy: 6
#          - Buy: 25
#          - Hold: 15
#          - Sell: 1
#          - Strong Sell: 1
#
#          Note: The numbers represent the number of analysts with each recommendation.
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: 5z5w9rw39
# DEBUG    ### Latest Information About Apple
#          To get the latest information about Apple, we need to consider various factors such as its stock price,
#          fundamentals, and analyst recommendations.
#
#
#          Running:
#           - get_current_stock_price(symbol=AAPL)
#           - get_stock_fundamentals(symbol=AAPL)
#           - get_analyst_recommendations(symbol=AAPL)
#
#          ## Latest Information About Apple
#          The current stock price of Apple (AAPL) is $252.68.
#
#          ### Stock Fundamentals
#          Here are the latest fundamentals for Apple:
#          * **Company Name:** Apple Inc.
#          * **Sector:** Technology
#          * **Industry:** Consumer Electronics
#          * **Market Cap:** $3,713,871,642,624
#          * **P/E Ratio:** 27.13
#          * **P/B Ratio:** 42.13
#          * **Dividend Yield:** 0.41
#          * **EPS:** 7.9
#          * **Beta:** 1.12
#          * **52-Week High:** $288.62
#          * **52-Week Low:** $169.21
#
#          ### Analyst Recommendations
#          The latest analyst recommendations for Apple are:
#          * **Strong Buy:** 6
#          * **Buy:** 25
#          * **Hold:** 15
#          * **Sell:** 1
#          * **Strong Sell:** 1
#
#          Note: The analyst recommendations are based on the latest data available and may not reflect the current
#          market situation.
# DEBUG    ============== tool ==============
# DEBUG    Tool call Id: a7r1x5f3f
# DEBUG
#          Running:
#           - duckduckgo_news(max_results=5, query=Apple news and updates)
#
#          ## Latest News About Apple
#          The latest news about Apple includes several updates and announcements. Here are some of the key points:
#          * Apple will host its annual Worldwide Developers Conference in June, showcasing AI advancements and new
#          software, including Maps ads.
#          * A conservative watchdog has called for the FTC to probe Apple News over allegations of anticompetitive
#          behavior and deceptive practices.
#          * Apple's AirDrop feature is now available on select Android devices, including the Samsung Galaxy S26.
#          * Apple has confirmed that it will bring ads to Maps as part of a new platform called Apple Business,
#          which will also offer advertising opportunities across Mail, Wallet, and Siri.
#          * Apple has announced WWDC 2026, which will include updates on iOS 27, a major Siri AI upgrade, and a
#          renewed focus on bug fixes and performance improvements across devices.
#
#          ### References:
#          * [USA TODAY](https://www.usatoday.com/story/tech/news/2026/03/24/apple-developer-event-june/89299084007/)
#          * [Fox
#          News](https://www.msn.com/en-us/news/technology/conservative-watchdog-calls-for-ftc-to-probe-apple-news-ov
#          er-anticompetitive-behavior-deceptive-practices/ar-AA1Z4JCM)
#          * [TechRepublic](https://www.techrepublic.com/article/news-samsung-galaxy-s26-airdrop-support/)
#          * [CNET](https://www.cnet.com/tech/services-and-software/apple-maps-ads-apple-business/)
#          * [TechRepublic](https://www.techrepublic.com/article/news-apple-wwdc-2026-ios-27-siri-ai-updates/)
# DEBUG    ============== assistant ==============
# DEBUG    ### Analyst Recommendations for Apple Stock
#          The analyst recommendations for Apple (AAPL) stock are as follows:
#          - Strong Buy: 6
#          - Buy: 25
#          - Hold: 15
#          - Sell: 1
#          - Strong Sell: 1
#
#          Note: The numbers represent the number of analysts with each recommendation.
#
#          ### Latest Information About Apple
#          The current stock price of Apple (AAPL) is $252.68.
#
#          ### Stock Fundamentals
#          Here are the latest fundamentals for Apple:
#          * **Company Name:** Apple Inc.
#          * **Sector:** Technology
#          * **Industry:** Consumer Electronics
#          * **Market Cap:** $3,713,871,642,624
#          * **P/E Ratio:** 27.13
#          * **P/B Ratio:** 42.13
#          * **Dividend Yield:** 0.41
#          * **EPS:** 7.9
#          * **Beta:** 1.12
#          * **52-Week High:** $288.62
#          * **52-Week Low:** $169.21
#
#          ### Analyst Recommendations
#          The latest analyst recommendations for Apple are:
#          * **Strong Buy:** 6
#          * **Buy:** 25
#          * **Hold:** 15
#          * **Sell:** 1
#          * **Strong Sell:** 1
#
#          Note: The analyst recommendations are based on the latest data available and may not reflect the current
#          market situation.
#
#          ### Latest News About Apple
#          The latest news about Apple includes several updates and announcements. Here are some of the key points:
#          * Apple will host its annual Worldwide Developers Conference in June, showcasing AI advancements and new
#          software, including Maps ads.
#          * A conservative watchdog has called for the FTC to probe Apple News over allegations of anticompetitive
#          behavior and deceptive practices.
#          * Apple's AirDrop feature is now available on select Android devices, including the Samsung Galaxy S26.
#          * Apple has confirmed that it will bring ads to Maps as part of a new platform called Apple Business,
#          which will also offer advertising opportunities across Mail, Wallet, and Siri.
#          * Apple has announced WWDC 2026, which will include updates on iOS 27, a major Siri AI upgrade, and a
#          renewed focus on bug fixes and performance improvements across devices.
#
#          ### References:
#          * [USA TODAY](https://www.usatoday.com/story/tech/news/2026/03/24/apple-developer-event-june/89299084007/)
#          * [Fox
#          News](https://www.msn.com/en-us/news/technology/conservative-watchdog-calls-for-ftc-to-probe-apple-news-ov
#          er-anticompetitive-behavior-deceptive-practices/ar-AA1Z4JCM)
#          * [TechRepublic](https://www.techrepublic.com/article/news-samsung-galaxy-s26-airdrop-support/)
#          * [CNET](https://www.cnet.com/tech/services-and-software/apple-maps-ads-apple-business/)
#          * [TechRepublic](https://www.techrepublic.com/article/news-apple-wwdc-2026-ios-27-siri-ai-updates/)
# DEBUG    **************** METRICS START ****************
# DEBUG    * Time to generate response:   1.5204s
# DEBUG    * Tokens per second:           410.4297 tokens/s
# DEBUG    * Input tokens:                1821
# DEBUG    * Output tokens:               624
# DEBUG    * Total tokens:                2445
# DEBUG    * Completion time:             0.8844s
# DEBUG    * Prompt time:                 0.2814s
# DEBUG    * Queue time:                  0.2770s
# DEBUG    * Total time:                  1.1658s
# DEBUG    **************** METRICS END ******************
# DEBUG    ---------- Groq Response End ----------
# DEBUG    Added 6 Messages to AgentMemory
# DEBUG    Added AgentRun to AgentMemory
# DEBUG    --**-- Logging Agent Run
# DEBUG    *********** Agent Run End: fbc19b1f-3cff-4dac-9d7f-cd7870fd1927 ***********

# %%
# Checking if there is valid content before saving
if response.strip():
    with open("results.md", "w", encoding="utf-8") as arquivo:
        arquivo.write("# ANALYST FINANCIAL REPORT\n\n")
        arquivo.write(response)

    print("[INFO] The results were saved in results.md")
else:
    print("[ERROR] The answer of the agent is empty.")
# Out:
# [INFO] The results were saved in results.md
